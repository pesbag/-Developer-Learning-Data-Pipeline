# %%
from operator import truediv

import pandas as pd
df=pd.read_csv("../AllDataFiles/developer_ai_learning_raw.csv")

# %%
print("the shape is:",df.shape)
df.info()
# Out:
# the shape is: (49191, 11)
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ResponseId       49191 non-null  int64
#  1   Age              49191 non-null  str
#  2   YearsCode        43042 non-null  float64
#  3   DevType          43680 non-null  str
#  4   LearnCodeChoose  46858 non-null  str
#  5   LearnCode        33556 non-null  str
#  6   LearnCodeAI      45201 non-null  str
#  7   AILearnHow       28257 non-null  str
#  8   AISelect         33720 non-null  str
#  9   AIAcc            33297 non-null  str
#  10  AISent           33467 non-null  str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 4.1 MB

# %%
print(df["AISent"].str.contains(";").sum())
# Out:
# 0

# %%
df["DevType"]
# Out:
# 0                       Developer, mobile
# 1                     Developer, back-end
# 2                    Developer, front-end
# 3                     Developer, back-end
# 4                     Engineering manager
#                        ...
# 49186                                 NaN
# 49187                                 NaN
# 49188    Architect, software or solutions
# 49189                                 NaN
# 49190                             Student
# Name: DevType, Length: 49191, dtype: str

# %%
df["LearnCodeChoose"]
# Out:
# 0        Yes, I am not new to coding but am learning ne...
# 1        Yes, I am not new to coding but am learning ne...
# 2        Yes, I am not new to coding but am learning ne...
# 3        Yes, I am not new to coding but am learning ne...
# 4        No, I am not new to coding and did not learn n...
#                                ...
# 49186                                                  NaN
# 49187    Yes, I am not new to coding but am learning ne...
# 49188    Yes, I am not new to coding but am learning ne...
# 49189    Yes, I am not new to coding but am learning ne...
# 49190    Yes, I am not new to coding but am learning ne...
# Name: LearnCodeChoose, Length: 49191, dtype: str

# %%
df["LearnCode"]
# Out:
# 0        Online Courses or Certification (includes all ...
# 1        Online Courses or Certification (includes all ...
# 2        Online Courses or Certification (includes all ...
# 3        Other online resources (e.g. standard search, ...
# 4                                                      NaN
#                                ...
# 49186                                                  NaN
# 49187    Online Courses or Certification (includes all ...
# 49188    Online Courses or Certification (includes all ...
# 49189    Videos (not associated with specific online co...
# 49190    Online Courses or Certification (includes all ...
# Name: LearnCode, Length: 49191, dtype: str

# %%
df["LearnCodeAI"]
# Out:
# 0        Yes, I learned how to use AI-enabled tools for...
# 1        Yes, I learned how to use AI-enabled tools for...
# 2        Yes, I learned how to use AI-enabled tools for...
# 3        Yes, I learned how to use AI-enabled tools for...
# 4        Yes, I learned how to use AI-enabled tools for...
#                                ...
# 49186                                                  NaN
# 49187    Yes, I learned how to use AI-enabled tools req...
# 49188    Yes, I learned how to use AI-enabled tools for...
# 49189    Yes, I learned how to use AI-enabled tools for...
# 49190    Yes, I learned how to use AI-enabled tools for...
# Name: LearnCodeAI, Length: 49191, dtype: str

# %%
print("total rows:",df["AILearnHow"].count())
print("seperate by ;\n",df["AILearnHow"].str.split(","))
# Out:
# total rows: 28257
# seperate by ;
#  0                    [AI CodeGen tools or AI-enabled apps]
# 1                    [AI CodeGen tools or AI-enabled apps]
# 2        [AI CodeGen tools or AI-enabled apps;Technical...
# 3        [AI CodeGen tools or AI-enabled apps;Videos (n...
# 4        [Technical documentation (is generated for/by ...
#                                ...
# 49186                                                  NaN
# 49187                                                  NaN
# 49188    [AI CodeGen tools or AI-enabled apps;Videos (n...
# 49189                                                  NaN
# 49190                [AI CodeGen tools or AI-enabled apps]
# Name: AILearnHow, Length: 49191, dtype: object

# %%
df["AISelect"]
# Out:
# 0        Yes, I use AI tools monthly or infrequently
# 1                         Yes, I use AI tools weekly
# 2                          Yes, I use AI tools daily
# 3                         Yes, I use AI tools weekly
# 4                         Yes, I use AI tools weekly
#                             ...
# 49186                                            NaN
# 49187                                            NaN
# 49188    Yes, I use AI tools monthly or infrequently
# 49189                                            NaN
# 49190                                            NaN
# Name: AISelect, Length: 49191, dtype: str

# %%
print("columns null:\n",df.isna().sum())
print("duplicates row:\n",df.duplicated().sum())
# Out:
# columns null:
#  ResponseId             0
# Age                    0
# YearsCode           6149
# DevType             5511
# LearnCodeChoose     2333
# LearnCode          15635
# LearnCodeAI         3990
# AILearnHow         20934
# AISelect           15471
# AIAcc              15894
# AISent             15724
# dtype: int64
# duplicates row:
#  0

# %%
print("devloper type:\n",list(df["DevType"].unique()))
# print("devloper type:\n",df["DevType"].unique())
# Out:
# devloper type:
#  ['Developer, mobile', 'Developer, back-end', 'Developer, front-end', 'Engineering manager', 'Developer, full-stack', 'Architect, software or solutions', 'Data engineer', 'Financial analyst or engineer', 'Academic researcher', 'Developer, embedded applications or devices', 'Cybersecurity or InfoSec professional', 'Developer, game or graphics', 'AI/ML engineer', 'Senior executive (C-suite, VP, etc.)', 'Developer, desktop or enterprise applications', 'Other (please specify):', 'Founder, technology or otherwise', 'Retired', 'Developer, AI apps or physical AI', 'DevOps engineer or professional', 'Student', 'Cloud infrastructure engineer', 'Project manager', 'Data scientist', 'Applied scientist', 'Data or business analyst', 'Product manager', 'System administrator', 'Support engineer or analyst', 'Developer, QA or test', 'Database administrator or engineer', 'UX, Research Ops or UI design professional', nan]

# %%
print("total Developer, mobile:\n",(df["DevType"]=="Developer, mobile").sum())
print("total Developer, front-end:\n",(df["DevType"]=="Developer, front-end").sum())
# Out:
# total Developer, mobile:
#  1391
# total Developer, front-end:
#  1974

# %%
df["AISelect"].tolist()
# Out:
# ['Yes, I use AI tools monthly or infrequently',
#  'Yes, I use AI tools weekly',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools weekly',
#  'Yes, I use AI tools weekly',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools monthly or infrequently',
#  "No, and I don't plan to",
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools monthly or infrequently',
#  nan,
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  "No, and I don't plan to",
#  'Yes, I use AI tools daily',
#  "No, and I don't plan to",
#  'Yes, I use AI tools daily',
#  "No, and I don't plan to",
#  "No, and I don't plan to",
#  'Yes, I use AI tools monthly or infrequently',
#  "No, and I don't plan to",
#  "No, and I don't plan to",
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools daily',
#  'Yes, I use AI tools weekly',
#  'Yes, I use AI tools daily',
# ...

# %%
df["LearnCodeChoose"].str.split(",")[0][0]
# Out:
# 'Yes'

# %%
print(df.shape[0])
len(list(df["ResponseId"].unique()))
# Out:
# 49191
# 49191

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ResponseId       49191 non-null  int64
#  1   Age              49191 non-null  str
#  2   YearsCode        43042 non-null  float64
#  3   DevType          43680 non-null  str
#  4   LearnCodeChoose  46858 non-null  str
#  5   LearnCode        33556 non-null  str
#  6   LearnCodeAI      45201 non-null  str
#  7   AILearnHow       28257 non-null  str
#  8   AISelect         33720 non-null  str
#  9   AIAcc            33297 non-null  str
#  10  AISent           33467 non-null  str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 4.1 MB
# None

# %%
df["YearsCode"]=pd.to_numeric(df["YearsCode"],errors='coerce').astype('Int64')

# %%
df["LearnCode"]=df["LearnCode"].str.split(";")
df["AILearnHow"]=df["AILearnHow"].str.split(";")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ResponseId       49191 non-null  int64
#  1   Age              49191 non-null  str
#  2   YearsCode        43042 non-null  Int64
#  3   DevType          43680 non-null  str
#  4   LearnCodeChoose  46858 non-null  str
#  5   LearnCode        33556 non-null  object
#  6   LearnCodeAI      45201 non-null  str
#  7   AILearnHow       28257 non-null  object
#  8   AISelect         33720 non-null  str
#  9   AIAcc            33297 non-null  str
#  10  AISent           33467 non-null  str
# dtypes: Int64(1), int64(1), object(2), str(7)
# memory usage: 4.2+ MB

# %%
df.to_json("cleaned_data.jsonl",orient='records',lines=True)

# %%
def experienceLevel_func(level):
    if pd.isna(level) or level is None:
        return "Unknown"
    elif 0<=level<=2:
        return "Beginner"
    elif level<=5:
        return "Early Career"
    elif level<=10:
        return "Experienced"
    elif level>10:
        return "Highly Experienced"


df["experienceLevel"]=df["YearsCode"].apply(experienceLevel_func)
df["experienceLevel"].value_counts()
# Out:
# experienceLevel
# Highly Experienced    25817
# Experienced           10365
# Unknown                6149
# Early Career           5153
# Beginner               1707
# Name: count, dtype: int64

# %%
print(df["LearnCode"][0])
print("\n",df["LearnCode"][1])
print("\n",df["LearnCode"][3])
print("\n",df["LearnCode"][4])
# Out:
# ['Online Courses or Certification (includes all media types)', 'Other online resources (e.g. standard search, forum, online community)']
#
#  ['Online Courses or Certification (includes all media types)', 'Other online resources (e.g. standard search, forum, online community)', 'Books / Physical media', 'Videos (not associated with specific online course or certification)', 'Stack Overflow or Stack Exchange']
#
#  ['Other online resources (e.g. standard search, forum, online community)', 'Videos (not associated with specific online course or certification)', 'Stack Overflow or Stack Exchange', 'Technical documentation (is generated for/by the tool or system)', 'AI CodeGen tools or AI-enabled apps']
#
#  nan

# %%
df["LearnCode"]
# Out:
# 0        [Online Courses or Certification (includes all...
# 1        [Online Courses or Certification (includes all...
# 2        [Online Courses or Certification (includes all...
# 3        [Other online resources (e.g. standard search,...
# 4                                                      NaN
#                                ...
# 49186                                                  NaN
# 49187    [Online Courses or Certification (includes all...
# 49188    [Online Courses or Certification (includes all...
# 49189    [Videos (not associated with specific online c...
# 49190    [Online Courses or Certification (includes all...
# Name: LearnCode, Length: 49191, dtype: object

# %%
RENAME_MAP = {
    "ResponseId": "responseId",
    "Age": "age",
    "YearsCode": "yearsCode",
    "DevType": "devType",
    "LearnCodeChoose": "learnCodeChoose",
    "LearnCode": "learningMethods",
    "LearnCodeAI": "learnCodeAI",
    "AILearnHow": "aiLearningMethods",
    "AISelect": "aiUsage",
    "AIAcc": "aiTrust",
    "AISent": "aiSentiment",
}

df = df.rename(columns=RENAME_MAP)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   responseId         49191 non-null  int64
#  1   age                49191 non-null  str
#  2   yearsCode          43042 non-null  Int64
#  3   devType            43680 non-null  str
#  4   learnCodeChoose    46858 non-null  str
#  5   learningMethods    33556 non-null  object
#  6   learnCodeAI        45201 non-null  str
#  7   aiLearningMethods  28257 non-null  object
#  8   aiUsage            33720 non-null  str
#  9   aiTrust            33297 non-null  str
#  10  aiSentiment        33467 non-null  str
#  11  experienceLevel    49191 non-null  str
# dtypes: Int64(1), int64(1), object(2), str(8)
# memory usage: 4.6+ MB

# %%
TECH_DOC = "Technical documentation (is generated for/by the tool or system)"
AI_CODEGEN = "AI CodeGen tools or AI-enabled apps"
STACK_OVERFLOW = "Stack Overflow or Stack Exchange"
def has_option(options, target):
    if isinstance(options, list):
        return target in options
    return False
df['usesDocumentation'] = df['learningMethods'].apply(lambda x: has_option(x, TECH_DOC))
df['usesAIForLearning'] = df['learningMethods'].apply(lambda x: has_option(x, AI_CODEGEN))
df['usesStackOverflow'] = df['learningMethods'].apply(lambda x: has_option(x, STACK_OVERFLOW))

# %%
df["experienceLevel"]
# Out:
# 0        Highly Experienced
# 1               Experienced
# 2        Highly Experienced
# 3              Early Career
# 4        Highly Experienced
#                 ...
# 49186               Unknown
# 49187               Unknown
# 49188    Highly Experienced
# 49189               Unknown
# 49190           Experienced
# Name: experienceLevel, Length: 49191, dtype: str

# %%
df['learningMethods'].contains('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['learningMethods'].contains('')
#
# File ~\PycharmProjects\PythonProject2\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'contains'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   responseId         49191 non-null  int64
#  1   age                49191 non-null  str
#  2   yearsCode          43042 non-null  Int64
#  3   devType            43680 non-null  str
#  4   learnCodeChoose    46858 non-null  str
#  5   learningMethods    33556 non-null  object
#  6   learnCodeAI        45201 non-null  str
#  7   aiLearningMethods  28257 non-null  object
#  8   aiUsage            33720 non-null  str
#  9   aiTrust            33297 non-null  str
#  10  aiSentiment        33467 non-null  str
#  11  experienceLevel    49191 non-null  str
#  12  usesDocumentation  49191 non-null  bool
#  13  usesAIForLearning  49191 non-null  bool
#  14  usesStackOverflow  49191 non-null  bool
# dtypes: Int64(1), bool(3), int64(1), object(2), str(8)
# memory usage: 4.7+ MB

# %%
df.isna().sum()
# Out:
# responseId               0
# age                      0
# yearsCode             6149
# devType               5511
# learnCodeChoose       2333
# learningMethods      15635
# learnCodeAI           3990
# aiLearningMethods    20934
# aiUsage              15471
# aiTrust              15894
# aiSentiment          15724
# experienceLevel          0
# usesDocumentation        0
# usesAIForLearning        0
# usesStackOverflow        0
# dtype: int64
